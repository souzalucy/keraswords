# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Embedding
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences

# %%
spam = pd.read_csv("spam.csv")

# %%
spam.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
spam.shape
# Out:
# (5572, 2)

# %%
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(spam['Category'])
print(y)
# Out:
# [0 0 1 ... 0 0 0]

# %%
mensagens = spam['Message'].values

# %%
X_train, x_test, y_train, y_test = train_test_split(mensagens, y, test_size=0.3)

# %%
token = Tokenizer(num_words=1000)
token.fit_on_texts(X_train)
token.fit_on_texts(x_test)
X_train = token.texts_to_sequences(X_train)
X_test = token.texts_to_sequences(x_test)

# %%
print(X_train)
# Out:
# [[301, 71, 10, 45, 3, 658, 52], [534, 60, 29, 74, 840, 1, 282, 67, 214, 390, 8, 5, 373, 7, 841, 555, 74, 72, 4], [195, 13, 97, 146, 118, 109, 336, 36, 4, 609, 153, 267, 16, 47, 659, 302, 129, 516, 686, 65, 413], [303, 301, 130, 147, 1, 796, 18, 3, 26, 8, 3], [3, 22, 295, 221, 31, 13, 97, 755, 47, 143, 187, 16, 633, 456, 610, 12, 65, 158], [718, 156, 77, 2, 198, 535, 80], [1, 108, 556, 75, 2, 21, 59], [391, 1, 226, 31, 536, 52, 634, 57, 14, 26, 196], [635, 191, 374, 337, 111, 9, 13, 16, 471, 375, 413, 16, 47, 901, 252, 660, 636], [3, 8, 13, 373, 1, 78, 4, 296], [50, 27, 247, 253, 199, 8, 110, 137, 5, 457, 842, 20, 199, 357, 351, 338, 7, 199, 5, 338], [687, 123, 22, 3, 80, 21], [84, 1, 222, 253, 3, 18, 40], [37, 10, 20, 3, 92, 175], [1, 62, 557, 88, 7, 1, 285, 2, 3, 71, 4, 94, 2, 392, 89, 47, 10, 188, 234, 131, 94, 85, 2, 318], [46, 82, 430, 1, 268, 39, 204, 31, 21, 176, 55, 365, 232, 154, 6, 248, 19, 49, 414, 41, 32, 4, 25, 902, 9, 472, 167, 21], [1, 62, 637, 15, 75, 243, 2, 12, 11, 263, 144, 63, 6, 75], [20, 489, 3, 58, 125, 4, 8, 96, 210, 264, 96, 210, 112, 21], [687, 56, 192, 10], [46, 339, 472, 6], [95, 95, 517, 1, 60, 8], [105, 68, 10, 4, 473, 81, 126, 30, 45, 7, 50, 121], [1, 33, 35, 415, 223, 3, 33, 35, 661, 51, 43, 42, 13], [130, 22, 3, 16, 10], [1, 16, 3, 103, 98, 17, 440, 34, 254, 10], [22, 3, 29, 142], [57, 50], [163, 27, 127, 5, 142, 31, 17, 4, 638, 64], [14, 9, 4, 56, 215, 30, 21, 269, 5, 2], [581, 187, 537, 208, 139], [195, 104, 16, 47, 376, 13, 903, 41, 283, 26, 159, 611, 490, 582, 179, 311, 340], [1, 204, 189, 5
, 2, 6, 492, 81], [12, 3, 909, 9, 36, 51, 20, 9, 25, 45, 3, 282, 1, 136, 395, 3, 3, 214, 18, 5, 396, 5, 45, 1, 478, 8, 1, 157, 39, 214, 75, 155, 3, 58, 80, 47, 289, 104, 98, 261, 7, 10, 14, 539, 10, 69, 2, 803, 2, 3], [312, 1, 93, 108, 23], [22, 3, 40, 121], [148, 165, 205, 397, 12, 13, 581, 187], [40, 9, 11, 146, 76], [46, 99, 184, 2, 3, 133], [534, 50, 27, 3, 55, 5], [95, 95, 50, 9, 13, 21], [266, 236, 17, 2, 35, 141, 134, 327, 20], [17, 3, 13, 302, 2, 962], [101, 167, 6, 17 ...

# %%
X_train = pad_sequences(X_train, padding='post', maxlen=500)
X_test = pad_sequences(X_test, padding='post', maxlen=500)

# %%
X_train
# Out:
# array([[208,  25, 381, ...,   0,   0,   0],
#        [ 53,  63, 146, ...,   0,   0,   0],
#        [ 39,  22,   2, ...,   0,   0,   0],
#        ...,
#        [395, 305,  39, ...,   0,   0,   0],
#        [  5, 148, 192, ...,   0,   0,   0],
#        [ 45, 115,   1, ...,   0,   0,   0]], dtype=int32)

# %%
len(token.word_index)
# Out:
# 9004

# %%
modelo = Sequential()
modelo.add(Embedding(input_dim=len(token.word_index), output_dim=50, input_length=500))
modelo.add(Flatten())
modelo.add(Dense(units=10, activation='relu'))
modelo.add(Dropout(0.1))
modelo.add(Dense(units=1, activation='sigmoid'))

# %%
modelo.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 50)           450200
#
#  flatten (Flatten)           (None, 25000)             0
#
#  dense (Dense)               (None, 10)                250010
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 700221 (2.67 MB)
# Trainable params: 700221 (2.67 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
modelo.fit(X_train, y_train, epochs=20, batch_size=10, verbose=True, validation_data=(X_train, y_train))
# Out:
# Epoch 1/20
# 390/390 [==============================] - 6s 16ms/step - loss: 0.0398 - accuracy: 0.9726 - val_loss: 0.0292 - val_accuracy: 0.9910
# Epoch 2/20
# 390/390 [==============================] - 6s 14ms/step - loss: 0.0311 - accuracy: 0.9790 - val_loss: 0.0243 - val_accuracy: 0.9941
# Epoch 3/20
# 390/390 [==============================] - 7s 17ms/step - loss: 0.0246 - accuracy: 0.9854 - val_loss: 0.0174 - val_accuracy: 0.9949
# Epoch 4/20
# 390/390 [==============================] - 6s 15ms/step - loss: 0.0212 - accuracy: 0.9851 - val_loss: 0.0137 - val_accuracy: 0.9962
# Epoch 5/20
# 390/390 [==============================] - 7s 18ms/step - loss: 0.0186 - accuracy: 0.9859 - val_loss: 0.0110 - val_accuracy: 0.9974
# Epoch 6/20
# 390/390 [==============================] - 5s 14ms/step - loss: 0.0172 - accuracy: 0.9854 - val_loss: 0.0093 - val_accuracy: 0.9974
# Epoch 7/20
# 390/390 [==============================] - 6s 17ms/step - loss: 0.0126 - accuracy: 0.9890 - val_loss: 0.0024 - val_accuracy: 0.9977
# Epoch 8/20
# 390/390 [==============================] - 6s 15ms/step - loss: 0.0084 - accuracy: 0.9895 - val_loss: 0.0022 - val_accuracy: 0.9979
# Epoch 9/20
# 390/390 [==============================] - 5s 14ms/step - loss: 0.0068 - accuracy: 0.9918 - val_loss: 0.0023 - val_accuracy: 0.9977
# Epoch 10/20
# 390/390 [==============================] - 6s 14ms/step - loss: 0.0078 - accuracy: 0.9897 - val_loss: 0.0022 - val_accuracy: 0.9979
# Epoch 11/20
# 390/390 [==============================] - 5s 13ms/step - loss: 0.0059 - accuracy: 0.9926 - val_loss: 0.0021 - val_accuracy: 0.9979
# Epoch 12/20
# 390/390 [==============================] - 7s 18ms/step - loss: 0.0072 - accuracy: 0.9900 - val_loss: 0.0021 - val_accuracy: 0.9979
# Epoch 13/20
# 390/390 [==============================] - 5s 14ms/step - loss: 0.0074 - accuracy: 0.9900 - val_loss: 0.0021 - val_accuracy: 0.9979
# Epoch 14/20
# 390/390 [==============================] - 6s 16ms/step - loss: 0.0066 - accuracy: 0.9915 - val_loss: 0.0021 - val_accuracy: 0.9977
# Epoch 15/20
# 390/390 [==============================] - 6s 16ms/step - loss: 0.0081 - accuracy: 0.9887 - val_loss: 0.0018 - val_accuracy: 0.9982
# Epoch 16/20
# 390/390 [==============================] - 5s 14ms/step - loss: 0.0060 - accuracy: 0.9910 - val_loss: 0.0018 - val_accuracy: 0.9982
# Epoch 17/20
# 390/390 [==============================] - 6s 16ms/step - loss: 0.0072 - accuracy: 0.9885 - val_loss: 0.0029 - val_accuracy: 0.9979
# Epoch 18/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0066 - accuracy: 0.9892 - val_loss: 0.0018 - val_accuracy: 0.9982
# Epoch 19/20
# 390/390 [==============================] - 6s 14ms/step - loss: 0.0071 - accuracy: 0.9867 - val_loss: 0.0018 - val_accuracy: 0.9982
# Epoch 20/20
# 390/390 [==============================] - 6s 17ms/step - loss: 0.0049 - accuracy: 0.9921 - val_loss: 0.0019 - val_accuracy: 0.9982

# %%
nova_previsao = modelo.predict(X_test)
print(nova_previsao)
# Out:
# 53/53 [==============================] - 0s 3ms/step
# [[1.6817615e-12]
#  [1.9252228e-07]
#  [9.0182695e-04]
#  ...
#  [1.7589082e-05]
#  [1.7716503e-10]
#  [1.3110039e-09]]

# %%
prev = (nova_previsao > 0.5)
print(prev)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
cm = confusion_matrix(y_test, prev)
print(cm)
# Out:
# [[1428   11]
#  [  19  214]]
